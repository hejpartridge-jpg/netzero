# %%
# =============================
# NET ZERO CO2 CALCULATOR v1
# DEFRA 2024 Emission Factors
# =============================

# --- USER INPUTS ---
# These will come from the app later, for now we define them here

# Heating
heating_type = "gas"          # "gas", "oil", "electric"
gas_kwh = 12000               # annual kWh from energy bill

# Electricity  
electricity_kwh = 3100        # annual kWh from energy bill

# Transport
car_type = "petrol"           # "petrol", "diesel", "electric", "none"
miles_per_year = 8000         # annual miles driven

# --- EMISSION FACTORS (DEFRA 2024) ---
FACTORS = {
    "gas":           0.18258,  # kg CO2e per kWh
    "oil":           0.24634,  # kg CO2e per kWh
    "electricity":   0.20705,  # kg CO2e per kWh (UK grid 2024)
    "car_petrol":    0.17362,  # kg CO2e per mile
    "car_diesel":    0.16393,  # kg CO2e per mile
    "car_electric":  0.05310,  # kg CO2e per mile
}
